# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
df_citylab_rdy = pd.read_csv("Citylab-Berlin_Projekte.csv", sep=";")
df_citylab_rdy.head()
# Out:
#   Projektname,Einsatzbereich,Web-Link,Ansprechperson,Email,Status,Kurzzusammenfassung,Webseite-Link,Quelle,Organisation,Art
# 0  BärGPT,"['Digitale Zusammenarbeit', 'Neue Tech...
# 1  Data Hub Berlin,"['Innovative Verwaltung', 'Of...
# 2  Partizipation Digital,"['Digitale Zusammenarbe...
# 3  GovTech TestLAB,"['Digitale Zusammenarbeit', '...
# 4  Stadtlabor2Go,"['Digitale Zusammenarbeit', 'In...

# %% [markdown]
# ***
# ## Main Page

# %%
url = 'https://citylab-berlin.org/de/projects/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
first_chunks = soup.find_all('div', class_='wpgb-masonry')

laufend_chunk = first_chunks[0].find_all('article')
abgeschlossen_chunk = first_chunks[1].find_all('article')

# %%
laufend_dict = {}

for tile in laufend_chunk: 
    sub_domain_link = tile.find('a', class_="wpgb-card-layer-link").get('href')
    h3 = tile.find('h3', class_="wpgb-block-3 wpgb-idle-scheme-1")
    if h3:
        textlink = h3.find('a')
        if textlink:
            title = textlink.text
    
    categeory_texts = []
    cat = tile.find('div', class_="wpgb-block-2")
    if cat: 
        categories = cat.find_all('a')
        if categories:
            for category in categories:
                categeory_text = category.text
                categeory_texts.append(categeory_text)
    
    laufend_dict[title] = {
        "sub-link" : sub_domain_link,
        "Einsatzbereich" : categeory_texts
    } 

for key in list(laufend_dict.keys()):
    split_string = re.split(r'[\\]', key)
    if split_string:  # Check if the split string has elements
        new_key = split_string[0].strip()
    laufend_dict[new_key] = laufend_dict.pop(key)

laufend_dict
# Out:
# {'BärGPT': {'sub-link': 'https://citylab-berlin.org/de/projects/baergpt/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit', 'Neue Technologien']},
#  'Data Hub Berlin': {'sub-link': 'https://citylab-berlin.org/de/projects/data-hub-berlin/',
#   'Einsatzbereich': ['Innovative Verwaltung', 'Offene Daten', 'Open Source']},
#  'Partizipation Digital': {'sub-link': 'https://citylab-berlin.org/de/projects/partizipation-digital/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit', 'Innovative Verwaltung']},
#  'GovTech TestLAB': {'sub-link': 'https://citylab-berlin.org/de/projects/govtech-testlab/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit',
#    'Innovative Verwaltung',
#    'Open Source']},
#  'Stadtlabor2Go': {'sub-link': 'https://citylab-berlin.org/de/projects/stadtlabor2go/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit',
#    'Innovative Verwaltung',
#    'Offene Daten, offene Städte']},
#  'Fairgnügen': {'sub-link': 'https://citylab-berlin.org/de/projects/fairgnuegen/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit',
#    'Innovative Verwaltung',
#    'Prototyping']},
#  'Kiezlabor': {'sub-link': 'https://citylab-berlin.org/de/projects/kiezlabor/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit',
#    'Innovative Verwaltung',
#    'Offene Daten, offene Städte',
#    'Smart Cities für alle']},
#  'Gieß den Kiez': {'sub-link': 'https://citylab-berlin.org/de/projects/giess-den-kiez/',
#   'Einsatzbereich': ['Energie und Nachhaltigkeit',
#    'Offene Daten, offene Städte']},
#  'Parla': {'sub-link': 'https://citylab-berlin.org/de/projects/parla/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit',
#    'Innovative Verwaltung',
#    'Neue Technologien']},
#  'KlimaDashboard Xhain': {'sub-link': 'https://citylab-berlin.org/de/projects/klimadashboard-xhain/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit',
#    'Energie und Nachhaltigkeit',
#    'Innovative Verwaltung']},
#  'Hilf-Mir.Berlin': {'sub-link': 'https://citylab-berlin.org/de/projects/hilf-mir-berlin/',
#   'Einsatzbereich': ['Innovative Verwaltung']},
#  'Talking Treebot': {'sub-link': 'https://citylab-berlin.org/de/projects/talking-treebot/',
#   'Einsatzbereich': ['Energie und Nachhaltigkeit',
#    'Offene Daten, offene Städte']},
#  'Bürgeramt der Zukunft': {'sub-link': 'https://citylab-berlin.org/de/projects/buergeramt-der-zukunft-tagebuchstudie/',
#   'Einsatzbereich': ['Innovative Verwaltung']},
#  'CityLAB Roadshow': {'sub-link': 'https://citylab-berlin.org/de/projects/citylab-roadshow/',
#   'Einsatzbereich': ['Innovative Verwaltung']},
#  'Berliner EnergieCheckpoint': {'sub-link': 'https://citylab-berlin.org/de/projects/berliner-energiecheckpoint/',
#   'Einsatzbereich': ['Offene Daten, offene Städte']},
#  'Gemeinsam Digital: Berlin': {'sub-link': 'https://citylab-berlin.org/de/projects/smart_city/',
#   'Einsatzbereich': ['Smart Cities für alle']},
#  'KI zum Anfassen': {'sub-link': 'https://citylab-berlin.org/de/projects/ki-zum-anfassen-unsere-interaktiven-exponate/',
#   'Einsatzbereich': ['Prototyping']},
#  'LabCamp': {'sub-link': 'https://citylab-berlin.org/de/projects/labcamp/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit',
#    'Innovative Verwaltung',
#    'Offene Daten, offene Städte',
#    'Digitale Zusammenarbeit']},
#  'Summer School': {'sub-link': 'https://citylab-berlin.org/de/projects/summerschool/',
#   'Einsatzbereich': ['Smart Cities für alle']},
#  'Berliner Weihnachtsmarkt-Finder': {'sub-link': 'https://citylab-berlin.org/de/projects/berliner-weihnachtsmarkt-finder/',
#   'Einsatzbereich': ['Offene Daten', 'offene Städte', 'Open Source']},
#  'Digitalwerkstatt Verwaltung': {'sub-link': 'https://citylab-berlin.org/de/projects/digitalwerkstatt/',
#   'Einsatzbereich': ['Innovative Verwaltung']},
#  'Werkstatt im CityLAB': {'sub-link': 'https://citylab-berlin.org/de/projects/werkstatt-im-citylab/',
#   'Einsatzbereich': ['Smart Cities für alle']},
#  'Hacking Box goes CityLAB Berlin': {'sub-link': 'https://citylab-berlin.org/de/projects/hacking-box-goes-citylab/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit']}}

# %%
abgeschlossen_dict = {}

for tile in abgeschlossen_chunk: 
    sub_domain_link = tile.find('a', class_="wpgb-card-layer-link").get('href')
    h3 = tile.find('h3', class_="wpgb-block-3 wpgb-idle-scheme-1")
    if h3:
        textlink = h3.find('a')
        if textlink:
            title = textlink.text

    categeory_texts = []
    cat = tile.find('div', class_="wpgb-block-2")
    if cat: 
        categories = cat.find_all('a')
        if categories:
            for category in categories:
                categeory_text = category.text
                categeory_texts.append(categeory_text)

    abgeschlossen_dict[title] = {
        "sub-link" : sub_domain_link,
        "Einsatzbereich" : categeory_texts
    } 

for key in list(abgeschlossen_dict.keys()):
    split_string = re.split(r'[\–\-\:]', key)
    if split_string:  # Check if the split string has elements
        new_key = split_string[0].strip()
    abgeschlossen_dict[new_key] = abgeschlossen_dict.pop(key)

abgeschlossen_dict
# Out:
# {'Digital Vereint': {'sub-link': 'https://citylab-berlin.org/de/projects/digitalvereint/',
#   'Einsatzbereich': ['Smart Cities für alle']},
#  'Quantified Trees (Qtrees)': {'sub-link': 'https://citylab-berlin.org/de/projects/qtrees/',
#   'Einsatzbereich': ['Energie und Nachhaltigkeit']},
#  'Verwaltungsdashboard': {'sub-link': 'https://citylab-berlin.org/de/projects/afs-dashboard/',
#   'Einsatzbereich': ['Innovative Verwaltung']},
#  'Stadtpuls': {'sub-link': 'https://citylab-berlin.org/de/projects/stadtpuls/',
#   'Einsatzbereich': ['Offene Daten, offene Städte', 'Smart Cities für alle']},
#  'Pixelwelt': {'sub-link': 'https://citylab-berlin.org/de/projects/pixelwelt/',
#   'Einsatzbereich': ['Digitale Zusammenarbeit']},
#  'Prototypenwerkstatt': {'sub-link': 'https://citylab-berlin.org/de/projects/prototypenwerkstatt/',
#   'Einsatzbereich': ['Innovative Verwaltung']},
#  'Prozessanalyse Radinfrastruktur (PARI)': {'sub-link': 'https://citylab-berlin.org/de/projects/prozessanalyse-radinfrastruktur-pari/',
#   'Einsatzbereich': ['Energie und Nachhaltigkeit',
#    'Offene Daten, offene Städte']},
#  'FixMyBerlin': {'sub-link': 'https://citylab-berlin.org/de/projects/digitale-tools-fuer-radwegeplanung/',
#   'Einsatzbereich': ['Innovative Verwaltung']},
#  'Berliner Erfrischungskarte': {'sub-link': 'https://citylab-berlin.org/de/projects/schatten/',
#   'Einsatzbereich': ['Offene Daten, offene Städte']},
#  'Clair Berlin': {'sub-link': 'https://citylab-berlin.org/de/projects/clair/',
#   'Einsatzbereich': ['Energie und Nachhaltigkeit']},
#  'AI for Berlin': {'sub-link': 'https://citylab-berlin.org/de/projects/aiforberlin/',
#   'Einsatzbereich': ['Offene Daten, offene Städte', 'Smart Cities für alle']},
#  'Shared Mobility Flows': {'sub-link': 'https://citylab-berlin.org/de/projects/bikesharing/',
#   'Einsatzbereich': ['Energie und Nachhaltigkeit',
#    'Offene Daten, offene Städte']},
#  'Open Traffic Count': {'sub-link': 'https://citylab-berlin.org/de/projects/trafficcount/',
#   'Einsatzbereich': ['Energie und Nachhaltigkeit',
#    'Offene Daten, offene Städte']},
#  'Bezirksregionen digital': {'sub-link': 'https://citylab-berlin.org/de/projects/districtprofiles/',
#   'Einsatzbereich': ['Innovative Verwaltung', 'Offene Daten, offene Städte']},
#  'Algorithmische Stadtvisionen': {'sub-link': 'https://citylab-berlin.org/de/projects/stadtvisionen/',
#   'Einsatzbereich': ['Neue Technologien']},
#  'Berlin Urban Tech': {'sub-link': 'https://citylab-berlin.org/de/projects/startupmapping/',
#   'Einsatzbereich': ['Offene Daten, offene Städte']},
#  'Prototype Your Future City!': {'sub-link': 'https://citylab-berlin.org/de/projects/prototype/',
#   'Einsatzbereich': ['Smart Cities für alle']}}

# %% [markdown]
# ***
# ## Subdomains

# %%
import json

abgeschlossen_soup_dict = {}

for key, values in abgeschlossen_dict.items():
    subdomain_url = values['sub-link']
    response_subdomain = requests.get(subdomain_url)
    subsoup = BeautifulSoup(response_subdomain.text, 'html.parser')
    abgeschlossen_soup_dict[key] = str(subsoup)

# %%
with open('abgeschlossen_soup_dict.json', 'w', encoding='utf-8') as f:
    json.dump(abgeschlossen_soup_dict, f)

# %%
laufend_soup_dict = {}

for key, values in laufend_dict.items():
    subdomain_url = values['sub-link']
    response_subdomain = requests.get(subdomain_url)
    subsoup = BeautifulSoup(response_subdomain.text, 'html.parser')
    laufend_soup_dict[key] = str(subsoup)

# %%
with open('laufend_soup_dict.json', 'w', encoding='utf-8') as f:
    json.dump(laufend_soup_dict, f)

# %%
for key, values in abgeschlossen_dict.items():
    subsoup = BeautifulSoup(abgeschlossen_soup_dict[key], 'html.parser')

    footer_div = subsoup.find('div', class_="site-footer")
    if footer_div:
        footer_div.extract()
    
    # Initialize variables to avoid NameError in the matrix
    web_link = None
    kontakt = None
    email = None
    status = None
    text = None
    
    # Extract web link - primary method
    link_header = subsoup.find('h2', class_="wp-block-heading", id="webseite")
    if link_header:
        web_link_container = link_header.find_next('a')
        if web_link_container:
            web_link = web_link_container.get('href')
    
    # Fallback to sub-link if primary method fails
    if web_link is None:
        web_link = abgeschlossen_dict[key]['sub-link']
    
    kontakt_header = subsoup.find(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'], string=lambda text: text and 'kontakt' in text.strip().lower())
    kontakt_container = kontakt_header.find_next('p')

    contacts = kontakt_container.find_all('a')
    emails = []
    kontakte = []
    for contact in contacts:
        contact_text = contact.get_text(strip=True)
        kontakte.append(contact_text)

        href = contact.get('href')
        # Special case for "CityLAB Berlin" - hardcoded like a corpo backdoor
        if contact_text == "CityLAB Berlin":
            emails.append("info@citylab-berlin.org")
        # Extract email from mailto: links
        elif href.startswith('mailto:'):
            email = href.replace('mailto:', '').strip()
            emails.append(email)
        # Capture any other hrefs too, bredrin
        elif href:
            emails.append(href)

    status = "Projekt Abgeschlossen"

    content = subsoup.find('div', class_="entry-content")
    if content: 
        warum_text = content.find_next('p')
        if warum_text:
            text = warum_text.get_text(strip=True)
    
    # Update the data structure
    values.update({
        "Webseite-Link": web_link,
        "Ansprechperson": kontakte,
        "Email": emails,
        "Status": status,
        "Kurzzusammenfassung": text
    })

# %%
for key, values in laufend_dict.items():
    subsoup = BeautifulSoup(laufend_soup_dict[key], 'html.parser')

    footer_div = subsoup.find('div', class_="site-footer")
    if footer_div:
        footer_div.extract()
    
    # Initialize variables to avoid NameError in the matrix
    web_link = None
    kontakt = None
    email = None
    status = None
    text = None
    
    # Extract web link - primary method
    link_header = subsoup.find('h2', class_="wp-block-heading", id="webseite")
    if link_header:
        web_link_container = link_header.find_next('a')
        if web_link_container:
            web_link = web_link_container.get('href')
    
    # Fallback to sub-link if primary method fails
    if web_link is None:
        web_link = laufend_dict[key]['sub-link']
    
    kontakt_header = subsoup.find(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'], string=lambda text: text and 'kontakt' in text.strip().lower())
    if kontakt_header:
        kontakt_container = kontakt_header.find_next('p')

    contacts = kontakt_container.find_all('a')
    emails = []
    kontakte = []
    for contact in contacts:
        contact_text = contact.get_text(strip=True)
        kontakte.append(contact_text)

        href = contact.get('href')
        # Special case for "CityLAB Berlin" - hardcoded like a corpo backdoor
        if contact_text == "CityLAB Berlin":
            emails.append("info@citylab-berlin.org")
        # Extract email from mailto: links
        elif href.startswith('mailto:'):
            email = href.replace('mailto:', '').strip()
            emails.append(email)
        # Capture any other hrefs too, bredrin
        elif href:
            emails.append(href)

    status = "Laufend"

    content = subsoup.find('div', class_="entry-content")
    if content: 
        warum_text = content.find_next('p')
        if warum_text:
            text = warum_text.get_text(strip=True)
    
    # Update the data structure
    values.update({
        "Webseite-Link": web_link,
        "Ansprechperson": kontakte,
        "Email": emails,
        "Status": status,
        "Kurzzusammenfassung": text
    })

# %%
with open('laufend_dict_working.json', 'w', encoding='utf-8') as f:
    json.dump(laufend_dict, f, ensure_ascii=False, indent=4)

with open('abgeschlossen_dict_working.json', 'w', encoding='utf-8') as f:
    json.dump(abgeschlossen_dict, f, ensure_ascii=False, indent=4)

# %%
df_abgeschlossen = pd.DataFrame()

df_abgeschlossen["Projektname"] = abgeschlossen_dict.keys()
values_df = pd.DataFrame(list(abgeschlossen_dict.values()))
df_abgeschlossen = pd.concat([df_abgeschlossen, values_df], axis=1)

# %%
df_abgeschlossen
# Out:
#                                Projektname  ...                                Kurzzusammenfassung
# 0                          Digital Vereint  ...  Für die vielen engagierten Vereine und Initiat...
# 1                Quantified Trees (Qtrees)  ...  Gefördert vom Bundesministerium für Umwelt, Na...
# 2                     Verwaltungsdashboard  ...  In vielen Bereichen der Berliner Verwaltung we...
# 3                                Stadtpuls  ...  Stadtpuls ist eine offene IoT-Datenplattform, ...
# 4                                Pixelwelt  ...  Super Mario war gestern, jetzt gibts das Super...
# 5                      Prototypenwerkstatt  ...  Das Projekt „Prototypenwerkstatt“ ist eine Koo...
# 6   Prozessanalyse Radinfrastruktur (PARI)  ...  Radfahren ist gut für das Klima, gegen Stau un...
# 7                              FixMyBerlin  ...  FixMyBerlin begleitet die Berliner Verwaltung ...
# 8               Berliner Erfrischungskarte  ...  Klimatische Unterschiede in der Stadt besser v...
# 9                             Clair Berlin  ...  Clair Berlin war eine gemeinwohlorientierte In...
# 10                           AI for Berlin  ...  In den letzten Jahren konnte man das Potenzial...
# 11                   Shared Mobility Flows  ...  Immer mehr Mobilitäts-Sharing-Anbieter (Leihfa...
# 12                      Open Traffic Count  ...  Autos, Fahrräder und Fußgänger im Straßenverke...
# 13                 Bezirksregionen digital  ...  Die Berliner Bezirke veröffentlichen regelmäßi...
# 14            Algorithmische Stadtvisionen  ...  Wie die Stadt der Zukunft aussehen wird, kann ...
# 15                       Berlin Urban Tech  ...  Urban Impact vernetzt europaweit Startups und ...
# 16             Prototype Your Future City!  ...  Im Rahmen eines dreitägigen interdisziplinären...
#
# [17 rows x 8 columns]

# %%
df_laufend = pd.DataFrame()

df_laufend["Projektname"] = laufend_dict.keys()
values_df = pd.DataFrame(list(laufend_dict.values()))
df_laufend = pd.concat([df_laufend, values_df], axis=1)

# %%
df_citylab_working = pd.DataFrame()

df_citylab_working = pd.concat([df_laufend, df_abgeschlossen])
df_citylab_working.reset_index(drop=True, inplace=True)

# %%
df_citylab_working
# Out:
#                                Projektname  ...                                Kurzzusammenfassung
# 0                                   BärGPT  ...  Bis 2030 gehen voraussichtlich rund 30 Prozent...
# 1                          Data Hub Berlin  ...  Luftqualität, Stauwarnungen oder digitale Serv...
# 2                    Partizipation Digital  ...  Im Rahmen unseres Fokusthemas „Ankommen in Ber...
# 3                          GovTech TestLAB  ...  Die Herausforderungen der Berliner Verwaltungs...
# 4                            Stadtlabor2Go  ...  Viele Kommunen stehen vor der Herausforderung,...
# 5                               Fairgnügen  ...  Berlin bietet eine Fülle an ermäßigten oder ko...
# 6                                Kiezlabor  ...                                               None
# 7                            Gieß den Kiez  ...  Die Folgen der Klimakrise in den Städten sind ...
# 8                                    Parla  ...  Welche Nachhaltigkeitsziele verfolgt der Berli...
# 9                     KlimaDashboard Xhain  ...  Der Berliner Senat verfolgt eine ambitionierte...
# 10                         Hilf-Mir.Berlin  ...  Berlin bietet ein breites Angebot für Menschen...
# 11                         Talking Treebot  ...  Bereits seit dem Launch vonGieß den KiezAnfang...
# 12                   Bürgeramt der Zukunft  ...  Wie könnten Berliner Bürger:innen schneller Te...
# 13                        CityLAB Roadshow  ...  Mit voll gepackten Methodenkoffern und dem Cit...
# 14              Berliner EnergieCheckpoint  ...  Wie hoch ist der jährliche Energieverbrauch de...
# 15               Gemeinsam Digital: Berlin  ...  Ende 2022 wurde die StrategieGemeinsam Digital...
# 16                         KI zum Anfassen  ...  Das Thema Künstliche Intelligenz (KI) ist zurz...
# 17                                 LabCamp  ...  In den letzten sechs Jahren sind vielzählige I...
# 18                           Summer School  ...  Berlin steht im Zuge der Digitalisierung vor z...
# 19         Berliner Weihnachtsmarkt-Finder  ...  Alle Jahre wieder veröffentlicht die Senatsver...
# 20             Digitalwerkstatt Verwaltung  ...  Zusammen mit der Senatsverwaltung für Inneres ...
# 21                    Werkstatt im CityLAB  ...  Die „Werkstatt im CityLAB“ ist ein Raum für Ex...
# 22         Hacking Box goes CityLAB Berlin  ...  Die Technologiestiftung öffnet die Blackboxes ...
# 23                         Digital Vereint  ...  Für die vielen engagierten Vereine und Initiat...
# 24               Quantified Trees (Qtrees)  ...  Gefördert vom Bundesministerium für Umwelt, Na...
# 25                    Verwaltungsdashboard  ...  In vielen Bereichen der Berliner Verwaltung we...
# 26                               Stadtpuls  ...  Stadtpuls ist eine offene IoT-Datenplattform, ...
# 27                               Pixelwelt  ...  Super Mario war gestern, jetzt gibts das Super...
# 28                     Prototypenwerkstatt  ...  Das Projekt „Prototypenwerkstatt“ ist eine Koo...
# 29  Prozessanalyse Radinfrastruktur (PARI)  ...  Radfahren ist gut für das Klima, gegen Stau un...
# 30                             FixMyBerlin  ...  FixMyBerlin begleitet die Berliner Verwaltung ...
# 31              Berliner Erfrischungskarte  ...  Klimatische Unterschiede in der Stadt besser v...
# 32                            Clair Berlin  ...  Clair Berlin war eine gemeinwohlorientierte In...
# 33                           AI for Berlin  ...  In den letzten Jahren konnte man das Potenzial...
# 34                   Shared Mobility Flows  ...  Immer mehr Mobilitäts-Sharing-Anbieter (Leihfa...
# 35                      Open Traffic Count  ...  Autos, Fahrräder und Fußgänger im Straßenverke...
# 36                 Bezirksregionen digital  ...  Die Berliner Bezirke veröffentlichen regelmäßi...
# 37            Algorithmische Stadtvisionen  ...  Wie die Stadt der Zukunft aussehen wird, kann ...
# 38                       Berlin Urban Tech  ...  Urban Impact vernetzt europaweit Startups und ...
# 39             Prototype Your Future City!  ...  Im Rahmen eines dreitägigen interdisziplinären...
#
# [40 rows x 8 columns]

# %%
df_citylab_working["Organisation"] = "CityLAB-Berlin"
df_citylab_working["Art"] = None
df_citylab_working.rename(columns={'sub-link': 'Quelle'}, inplace=True)

# %%
df_citylab_working.to_csv('Citylab-Berlin_Projekte.csv', index=False)
