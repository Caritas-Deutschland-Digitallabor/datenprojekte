# %% [markdown]
# https://www.civic-coding.de/community-information/projekte

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
df_civiccoding = pd.read_csv("CivicCoding_Projekte.csv", sep=";")
df_civiccoding.head()
# Out:
# Empty DataFrame
# Columns: [Quelle, Projektname, Art, Einsatzbereich, Webseite-Link, Organisation, Ansprechperson, Email, Status, Kurzzusammenfassung, Unnamed: 10]
# Index: []

# %%
https://www.civic-coding.de/community-information/projekte?tx_solr%5BresultsPerPage%5D=20

# %%
url1 = "https://www.civic-coding.de/community-information/projekte?tx_solr%5Bpage%5D=1"
url2 = "https://www.civic-coding.de/community-information/projekte?tx_solr%5Bpage%5D=2"
url3 = "https://www.civic-coding.de/community-information/projekte?tx_solr%5Bpage%5D=3"
url4 = "https://www.civic-coding.de/community-information/projekte?tx_solr%5Bpage%5D=4"
url5 = "https://www.civic-coding.de/community-information/projekte?tx_solr%5Bpage%5D=5"

url_list = [url1, url2, url3, url4, url5]

# %%
soup_list = []

for index in range(20):
    url = f"https://www.civic-coding.de/community-information/projekte?tx_solr%5Bpage%5D={index}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    soup_list.append(soup)

# %%
all_link_list = []
for soup in soup_list:
    link_list = []
    project_list = soup.find_all('a', class_="position-absolute top-0 bottom-0 start-0 end-0 z-1 projectidea-link")
    
    for project in project_list:
        link = project.get('href')
        if link:  
            full_link = "https://www.civic-coding.de" + link  
            link_list.append(full_link)
    
    print(len(link_list))
    all_link_list.extend(link_list)
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 13
# 12
# 15
# 15
# 20
# 9
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
df_civiccoding["Quelle"] = all_link_list

# %%
df_civiccoding.to_csv("CivicCoding_Projekte.csv")
